# %% [markdown]
# # Test Technique : Bevouac

# %% [markdown]
# ## Module 1 : Scrapping

# %% [markdown]
# - Téléchargement du fichier contenant le fichier full.csv

# %%
#imports 
import json
import tempfile
import numpy as np
import pandas as pd

# IMPORTING MODULES
import os
import zipfile
import tarfile
import gzip
import shutil
import requests

#extraction du fichier suivant l'url et téléchargement dans le fichier souhaité 
# ARCHIVE EXTENSIONS
ZIP_EXTENSION = ".zip"
TAR_EXTENSION = ".tar"
TAR_GZ_EXTENSION = ".tar.gz"
TGZ_EXTENSION = ".tgz"
GZ_EXTENSION = ".gz"
EMPTY_URL_ERROR = "ERROR: URL should not be empty."
FILENAME_ERROR = "ERROR: Filename should not be empty."
UNKNOWN_FORMAT = "ERROR: Unknown file format. Can't extract."
with tempfile.TemporaryDirectory() as tmpdirname:
        print('created temporary directory', tmpdirname)

#enregistrer le fichier souhaité dans le fichier concerné dans notre cas enregistré dans le fichier de téléchargement
def download_dataset(url, target_path="data/", keep_download=True, overwrite_download=False):
    """Downloads dataset from a url.
    url: string, a dataset path
    target_path: string, path where data will be downloaded
    keep_download: boolean, keeps the original file after extraction
    overwrite_download: boolean, stops download if dataset already exists
    """
    if url == "" or url is None:
        raise Exception(EMPTY_URL_ERROR)

    filename = get_filename(url)
    file_location = get_file_location(target_path, filename)

    os.makedirs(tmpdirname, exist_ok=True) #your downloading target path 

    if os.path.exists(file_location) and not overwrite_download:
        print(f"File already exists at {file_location}. Use: 'overwrite_download=True' to \
overwrite download")
        extract_file(target_path, filename)
        return

    print(f"Downloading file from {url} to {file_location}.")
    # Download
    with open(file_location, 'wb') as f:
        with requests.get(url, allow_redirects=True, stream=True) as resp:
            for chunk in resp.iter_content(chunk_size = 512):  #chunk_size in bytes
                if chunk:
                    f.write(chunk)

    print("Finished downloading.")
    print("Extracting the file now ...")
    extract_file(os.path.join(tmpdirname, '') , filename)

    if not keep_download:
        os.remove(file_location)

def extract_file(target_path, filename):
    """Extract file based on file extension
    target_path: string, location where data will be extracted
    filename: string, name of the file along with extension
    """
    if filename == "" or filename is None:
        raise Exception(FILENAME_ERROR)

    file_location = get_file_location(target_path, filename)

    if filename.endswith(ZIP_EXTENSION):
        print("Extracting zip file...")
        zipf = zipfile.ZipFile(file_location, 'r')
        zipf.extractall(target_path)
        zipf.close()
        print(' E N D')
    elif filename.endswith(TAR_EXTENSION) or \
         filename.endswith(TAR_GZ_EXTENSION) or \
         filename.endswith(TGZ_EXTENSION):
        print("Extracting tar file")
        tarf = tarfile.open(file_location, 'r')
        tarf.extractall(target_path)
        tarf.close()
        print(' E N D')
    elif filename.endswith(GZ_EXTENSION):
        print("Extracting gz file")
        out_file = file_location[:-3]
        with open(file_location, "rb") as f_in:
            with open(out_file, "wb") as f_out:
                shutil.copyfileobj(f_in, f_out)
                print(' E N D')
    else:
        print(UNKNOWN_FORMAT)

def get_filename(url):
    """Extract filename from file url"""
    filename = os.path.basename(url)
    return filename

def get_file_location(target_path, filename):
    """ Concatenate download directory and filename"""
    return target_path + filename
# Out:
# created temporary directory C:\Users\Lenovo\AppData\Local\Temp\tmp57hd229t

# %%
#download information and locations of the file (temporary directory)

print('name of file: ',get_filename("https://cadastre.data.gouv.fr/data/etalab-dvf/latest/csv/2020/full.csv.gz"))
download_dataset("https://cadastre.data.gouv.fr/data/etalab-dvf/latest/csv/2020/full.csv.gz",os.path.join(tmpdirname, ''),keep_download=True, overwrite_download=False)

pass #pass the  ignoring error message: the python code does not recognize the path, because the file is temporary
#this normally is not recommended, but we use it to overcome the error messages and download the dataset
#properly
# Out:
# name of file:  full.csv.gz
# Downloading file from https://cadastre.data.gouv.fr/data/etalab-dvf/latest/csv/2020/full.csv.gz to C:\Users\Lenovo\AppData\Local\Temp\tmp57hd229t\full.csv.gz.
# Finished downloading.
# Extracting the file now ...
# Extracting gz file
#  E N D

# %% [markdown]
# - Traitement Data

# %%
file_location = get_file_location(os.path.join(tmpdirname, ''), 'full.csv.gz')#obtaining file location

# %%
#pandas support zip file reads

#reading file
data_splited = pd.read_csv(file_location)
# Out:
# C:\Users\Lenovo\document2\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (10,12,17,18,20,22,35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_splited #voici le fichier avec ses caractéristiques
print(data_splited.shape, 'shape of data')
# Out:
# (827105, 40) shape of data

# %%
#del(data_splited['my_name'])#adding column
data_splited
# Out:
#         id_mutation date_mutation  numero_disposition nature_mutation  \
# 0            2020-1    2020-01-07                   1           Vente
# 1            2020-2    2020-01-07                   1           Vente
# 2            2020-3    2020-01-14                   1           Vente
# 3            2020-3    2020-01-14                   1           Vente
# 4            2020-4    2020-01-22                   1           Vente
# ...             ...           ...                 ...             ...
# 827100  2020-377318    2020-06-30                   1           Vente
# 827101  2020-377319    2020-06-26                   1           Vente
# 827102  2020-377320    2020-06-25                   1           Vente
# 827103  2020-377321    2020-06-23                   1           Vente
# 827104  2020-377322    2020-06-11                   1           Vente
#
#         valeur_fonciere  adresse_numero adresse_suffixe      adresse_nom_voie  \
# 0                8000.0             NaN             NaN              FORTUNAT
# 1               75000.0             NaN             NaN  RUE DE LA CHARTREUSE
# 2               89000.0             NaN             NaN             VACAGNOLE
# 3               89000.0             NaN             NaN             VACAGNOLE
# 4              209950.0            11.0             NaN             RUE REYER
# ...                 ...             ...             ...                   ...
# 827100         520000.0            55.0             NaN        RUE MONTMARTRE
# 827101        1740000.0           104.0             NaN           RUE REAUMUR
# 827102         725000.0            16.0             NaN       RUE CHARLEMAGNE
# 827103         200000.0             7.0             NaN         RUE CHABANAIS
# 827104         433000.0             3.0             NaN      RUE SAINT-JOSEPH
#
#        adresse_code_voie  code_postal  ...   type_local surface_reelle_bati  \
# 0                   B063       1250.0  ...          NaN                 NaN
# 1                   0064       1960.0  ...          NaN                 NaN
# 2                   B112       1340.0  ...          NaN                 NaN
# 3                   B112       1340.0  ...          NaN                 NaN
# 4                   3340       1000.0  ...       Maison                78.0
# ...                  ...          ...  ...          ...                 ...
# 827100              6513      75002.0  ...  Appartement                47.0
# 827101              8073      75002.0  ...  Appartement               150.0
# 827102              1797      75004.0  ...  Appartement                48.0
# 827103              1669      75002.0  ...  Appartement                26.0
# 827104              8659      75002.0  ...  Appartement                33.0
#
#        nombre_pieces_principales  code_nature_culture    nature_culture  \
# 0                            NaN                    T            terres
# 1                            NaN                   AB  terrains a bâtir
# 2                            NaN                   AB  terrains a bâtir
# 3                            NaN                   AB  terrains a bâtir
# 4                            5.0                    S              sols
# ...                          ...                  ...               ...
# 827100                       3.0                  NaN               NaN
# 827101                       5.0                  NaN               NaN
# 827102                       3.0                  NaN               NaN
# 827103                       1.0                  NaN               NaN
# 827104                       1.0                  NaN               NaN
#
#        code_nature_culture_speciale  nature_culture_speciale surface_terrain  \
# 0                               NaN                      NaN          1061.0
# 1                               NaN                      NaN           610.0
# 2                               NaN                      NaN           600.0
# 3                               NaN                      NaN           491.0
# 4                               NaN                      NaN           242.0
# ...                             ...                      ...             ...
# 827100                          NaN                      NaN             NaN
# 827101                          NaN                      NaN             NaN
# 827102                          NaN                      NaN             NaN
# 827103                          NaN                      NaN             NaN
# 827104                          NaN                      NaN             NaN
#
#        longitude   latitude
# 0       5.323522  46.171899
# 1       5.226197  46.184538
# 2            NaN        NaN
# 3            NaN        NaN
# 4       5.219902  46.196484
# ...          ...        ...
# 827100  2.344134  48.865842
# 827101  2.347903  48.867536
# 827102  2.359936  48.854633
# 827103  2.336652  48.867463
# 827104  2.345110  48.868196
#
# [827105 rows x 40 columns]

# %%
data_splited['NOM_CANDIDAT'] = 'MAAREF'#adding column with my name

# %%
data_splited = data_splited[['NOM_CANDIDAT','id_mutation', 'date_mutation', 'numero_disposition', 'nature_mutation',
       'valeur_fonciere', 'adresse_numero', 'adresse_suffixe',
       'adresse_nom_voie', 'adresse_code_voie', 'code_postal', 'code_commune',
       'nom_commune', 'code_departement', 'ancien_code_commune',
       'ancien_nom_commune', 'id_parcelle', 'ancien_id_parcelle',
       'numero_volume', 'lot1_numero', 'lot1_surface_carrez', 'lot2_numero',
       'lot2_surface_carrez', 'lot3_numero', 'lot3_surface_carrez',
       'lot4_numero', 'lot4_surface_carrez', 'lot5_numero',
       'lot5_surface_carrez', 'nombre_lots', 'code_type_local', 'type_local',
       'surface_reelle_bati', 'nombre_pieces_principales',
       'code_nature_culture', 'nature_culture', 'code_nature_culture_speciale',
       'nature_culture_speciale', 'surface_terrain', 'longitude', 'latitude',
       ]]#new column NOM_CANDIDAT in the first position

# %%
data_splited#new data frame with column NOM_CANDIDAT added
# Out:
#        NOM_CANDIDAT  id_mutation date_mutation  numero_disposition  \
# 0            MAAREF       2020-1    2020-01-07                   1
# 1            MAAREF       2020-2    2020-01-07                   1
# 2            MAAREF       2020-3    2020-01-14                   1
# 3            MAAREF       2020-3    2020-01-14                   1
# 4            MAAREF       2020-4    2020-01-22                   1
# ...             ...          ...           ...                 ...
# 827100       MAAREF  2020-377318    2020-06-30                   1
# 827101       MAAREF  2020-377319    2020-06-26                   1
# 827102       MAAREF  2020-377320    2020-06-25                   1
# 827103       MAAREF  2020-377321    2020-06-23                   1
# 827104       MAAREF  2020-377322    2020-06-11                   1
#
#        nature_mutation  valeur_fonciere  adresse_numero adresse_suffixe  \
# 0                Vente           8000.0             NaN             NaN
# 1                Vente          75000.0             NaN             NaN
# 2                Vente          89000.0             NaN             NaN
# 3                Vente          89000.0             NaN             NaN
# 4                Vente         209950.0            11.0             NaN
# ...                ...              ...             ...             ...
# 827100           Vente         520000.0            55.0             NaN
# 827101           Vente        1740000.0           104.0             NaN
# 827102           Vente         725000.0            16.0             NaN
# 827103           Vente         200000.0             7.0             NaN
# 827104           Vente         433000.0             3.0             NaN
#
#             adresse_nom_voie adresse_code_voie  ...   type_local  \
# 0                   FORTUNAT              B063  ...          NaN
# 1       RUE DE LA CHARTREUSE              0064  ...          NaN
# 2                  VACAGNOLE              B112  ...          NaN
# 3                  VACAGNOLE              B112  ...          NaN
# 4                  RUE REYER              3340  ...       Maison
# ...                      ...               ...  ...          ...
# 827100        RUE MONTMARTRE              6513  ...  Appartement
# 827101           RUE REAUMUR              8073  ...  Appartement
# 827102       RUE CHARLEMAGNE              1797  ...  Appartement
# 827103         RUE CHABANAIS              1669  ...  Appartement
# 827104      RUE SAINT-JOSEPH              8659  ...  Appartement
#
#        surface_reelle_bati nombre_pieces_principales code_nature_culture  \
# 0                      NaN                       NaN                   T
# 1                      NaN                       NaN                  AB
# 2                      NaN                       NaN                  AB
# 3                      NaN                       NaN                  AB
# 4                     78.0                       5.0                   S
# ...                    ...                       ...                 ...
# 827100                47.0                       3.0                 NaN
# 827101               150.0                       5.0                 NaN
# 827102                48.0                       3.0                 NaN
# 827103                26.0                       1.0                 NaN
# 827104                33.0                       1.0                 NaN
#
#           nature_culture  code_nature_culture_speciale  \
# 0                 terres                           NaN
# 1       terrains a bâtir                           NaN
# 2       terrains a bâtir                           NaN
# 3       terrains a bâtir                           NaN
# 4                   sols                           NaN
# ...                  ...                           ...
# 827100               NaN                           NaN
# 827101               NaN                           NaN
# 827102               NaN                           NaN
# 827103               NaN                           NaN
# 827104               NaN                           NaN
#
#        nature_culture_speciale  surface_terrain longitude   latitude
# 0                          NaN           1061.0  5.323522  46.171899
# 1                          NaN            610.0  5.226197  46.184538
# 2                          NaN            600.0       NaN        NaN
# 3                          NaN            491.0       NaN        NaN
# 4                          NaN            242.0  5.219902  46.196484
# ...                        ...              ...       ...        ...
# 827100                     NaN              NaN  2.344134  48.865842
# 827101                     NaN              NaN  2.347903  48.867536
# 827102                     NaN              NaN  2.359936  48.854633
# 827103                     NaN              NaN  2.336652  48.867463
# 827104                     NaN              NaN  2.345110  48.868196
#
# [827105 rows x 41 columns]

# %%
adresse = pd.concat([data_splited["adresse_numero"], data_splited["adresse_nom_voie"], data_splited["nom_commune"],data_splited["code_postal"]], axis=1)

# %%
adresse["pays"] = 'FRANCE' #adding the column 'pays'

# %%
adresse['code_postal'] = adresse['code_postal'].values.astype(int) #converting postal code to int

adresse#creating a dataframe adresse that we will use to merge the columns
# Out:
#         adresse_numero      adresse_nom_voie              nom_commune  \
# 0                  NaN              FORTUNAT                Ceyzériat
# 1                  NaN  RUE DE LA CHARTREUSE                 Péronnas
# 2                  NaN             VACAGNOLE                 Attignat
# 3                  NaN             VACAGNOLE                 Attignat
# 4                 11.0             RUE REYER          Bourg-en-Bresse
# ...                ...                   ...                      ...
# 827100            55.0        RUE MONTMARTRE  Paris 2e Arrondissement
# 827101           104.0           RUE REAUMUR  Paris 2e Arrondissement
# 827102            16.0       RUE CHARLEMAGNE  Paris 4e Arrondissement
# 827103             7.0         RUE CHABANAIS  Paris 2e Arrondissement
# 827104             3.0      RUE SAINT-JOSEPH  Paris 2e Arrondissement
#
#         code_postal    pays
# 0              1250  FRANCE
# 1              1960  FRANCE
# 2              1340  FRANCE
# 3              1340  FRANCE
# 4              1000  FRANCE
# ...             ...     ...
# 827100        75002  FRANCE
# 827101        75002  FRANCE
# 827102        75004  FRANCE
# 827103        75002  FRANCE
# 827104        75002  FRANCE
#
# [827105 rows x 5 columns]

# %%
data_splited['adresse_string'] = adresse[adresse.columns[0:]].apply(
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1) #merging different columns from the data frame adresse and creating the column 'adresse_string'
# Out:
# <ipython-input-64-9d1daff3195f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_splited['adresse_string'] = adresse[adresse.columns[0:]].apply(

# %%
data_splited['adresse_string'] #data tranformed with the right form
#NUMERO_RUE NOM_RUE NOM_VILLE CODE_POSTAL PAYS
# Out:
# 0                            FORTUNAT Ceyzériat 1250 FRANCE
# 1                 RUE DE LA CHARTREUSE Péronnas 1960 FRANCE
# 2                            VACAGNOLE Attignat 1340 FRANCE
# 3                            VACAGNOLE Attignat 1340 FRANCE
# 4                11.0 RUE REYER Bourg-en-Bresse 1000 FRANCE
#                                 ...
# 827100    55.0 RUE MONTMARTRE Paris 2e Arrondissement 75...
# 827101    104.0 RUE REAUMUR Paris 2e Arrondissement 7500...
# 827102    16.0 RUE CHARLEMAGNE Paris 4e Arrondissement 7...
# 827103    7.0 RUE CHABANAIS Paris 2e Arrondissement 7500...
# 827104    3.0 RUE SAINT-JOSEPH Paris 2e Arrondissement 7...
# Name: adresse_string, Length: 827105, dtype: object

# %%
#delete Nan lines from the dataframe in the columns 'longitudes ' and 'latitudes'

data_splited.dropna(subset=["longitude"], axis=0, inplace=True)
data_splited.dropna(subset=["latitude"], axis=0, inplace=True)

data_splited['valeur_fonciere'] = data_splited['valeur_fonciere'].values.astype(int)
data_splited['longitude'] = data_splited['longitude'].values.astype(float)
data_splited['latitude'] = data_splited['latitude'].values.astype(float)

# %%
data_splited #data with all existing longitude and latitude
# Out:
#        NOM_CANDIDAT  id_mutation date_mutation  numero_disposition  \
# 0            MAAREF  2020-117283    2020-01-01                   1
# 1            MAAREF  2020-160394    2020-01-01                   1
# 2            MAAREF   2020-29335    2020-01-01                   1
# 3            MAAREF   2020-29335    2020-01-01                   1
# 4            MAAREF  2020-156084    2020-01-02                   1
# ...             ...          ...           ...                 ...
# 780126       MAAREF  2020-361773    2020-06-30                   1
# 780127       MAAREF    2020-8121    2020-06-30                   1
# 780128       MAAREF  2020-216822    2020-06-30                   1
# 780129       MAAREF  2020-216823    2020-06-30                   1
# 780130       MAAREF  2020-242000    2020-06-30                   1
#
#        nature_mutation  valeur_fonciere  adresse_numero adresse_suffixe  \
# 0                Vente             2055             NaN             NaN
# 1                Vente           100000             3.0             NaN
# 2                Vente           195000            11.0             NaN
# 3                Vente           195000            11.0             NaN
# 4                Vente           428000            28.0             NaN
# ...                ...              ...             ...             ...
# 780126           Vente         33100000            66.0             NaN
# 780127           Vente            35000          5136.0             NaN
# 780128           Vente            35000            62.0             NaN
# 780129           Vente           162000             NaN             NaN
# 780130           Vente           172000            16.0             NaN
#
#             adresse_nom_voie adresse_code_voie  ...  surface_reelle_bati  \
# 0                  LA QUERLA              B147  ...                  NaN
# 1        RUE DU JEU DE BOULE              0080  ...                 75.0
# 2        RUE SAUVEUR TOBELEM              8654  ...                  NaN
# 3        RUE SAUVEUR TOBELEM              8654  ...                 53.0
# 4                RUE PALISSY              2910  ...                 21.0
# ...                      ...               ...  ...                  ...
# 780126       RUE DE PONTHIEU              7612  ...                 37.0
# 780127         EYGUIANS GARE              B012  ...                  NaN
# 780128  RUE GRASSIN BALEDANS              1900  ...                 18.0
# 780129        LE VILLAGE EST              B030  ...                  NaN
# 780130  RUE DE L ARTHUISIERE              0120  ...                 48.0
#
#        nombre_pieces_principales code_nature_culture nature_culture  \
# 0                            NaN                   L         landes
# 1                            3.0                   S           sols
# 2                            0.0                 NaN            NaN
# 3                            2.0                 NaN            NaN
# 4                            1.0                   S           sols
# ...                          ...                 ...            ...
# 780126                       1.0                   S           sols
# 780127                       0.0                   T         terres
# 780128                       1.0                 NaN            NaN
# 780129                       NaN                   J        jardins
# 780130                       2.0                   S           sols
#
#         code_nature_culture_speciale  nature_culture_speciale surface_terrain  \
# 0                              PATUR           Pâture plantée         10276.0
# 1                                NaN                      NaN           122.0
# 2                                NaN                      NaN             NaN
# 3                                NaN                      NaN             NaN
# 4                                NaN                      NaN           103.0
# ...                              ...                      ...             ...
# 780126                           NaN                      NaN           767.0
# 780127                           NaN                      NaN          1175.0
# 780128                           NaN                      NaN             NaN
# 780129                           NaN                      NaN           550.0
# 780130                           NaN                      NaN          2225.0
#
#         longitude   latitude  \
# 0        6.190460  45.098818
# 1       -0.558756  47.421083
# 2        5.365564  43.288497
# 3        5.365564  43.288497
# 4        0.614380  44.200272
# ...           ...        ...
# 780126   2.305291  48.872334
# 780127   5.769950  44.345989
# 780128   2.789443  50.287285
# 780129   3.006803  50.248522
# 780130  -0.060393  47.714647
#
#                                            adresse_string
# 0                            LA QUERLA Besse 38142 FRANCE
# 1       3.0 RUE DU JEU DE BOULE Sainte-Gemmes-sur-Loir...
# 2       11.0 RUE SAUVEUR TOBELEM Marseille 7e Arrondis...
# 3       11.0 RUE SAUVEUR TOBELEM Marseille 7e Arrondis...
# 4                      28.0 RUE PALISSY Agen 47000 FRANCE
# ...                                                   ...
# 780126  66.0 RUE DE PONTHIEU Paris 8e Arrondissement 7...
# 780127     5136.0 EYGUIANS GARE Garde-Colombe 5300 FRANCE
# 780128       62.0 RUE GRASSIN BALEDANS Arras 62000 FRANCE
# 780129                   LE VILLAGE EST Dury 62156 FRANCE
# 780130   16.0 RUE DE L ARTHUISIERE La Flèche 72200 FRANCE
#
# [780131 rows x 42 columns]

# %%
print(data_splited.shape, '--> new shape after dropping NaN values in columns longitude and latitude')
# Out:
# (780131, 42) --> new shape after dropping NaN values in columns longitude and latitude

# %%
data_splited.reset_index(drop=True, inplace=True)#reset index with new number of lines 
data_splited.to_csv(r'C:\Users\Lenovo\Desktop\Bevouac\data_splited.csv', index=False)

# %% [markdown]
# ## Module 2 : Import de données

# %% [markdown]
# - Dans cette partie nous allons afficher les 500 dates les plus récentes
# - Nous allons par la suite charger le nouveau dataframe dans la base Airtable

# %%
#data_splited['date_mutation'] = pd.to_datetime(data_splited['date_mutation'])
data_splited = data_splited.sort_values('date_mutation')

data_splited.reset_index(drop=True, inplace=True)#reset index with new number of lines 
data_splited.head(500)#We use head to obtain the 500 recent dates
# Out:
#     NOM_CANDIDAT  id_mutation date_mutation  numero_disposition  \
# 0         MAAREF  2020-117283    2020-01-01                   1
# 1         MAAREF  2020-160394    2020-01-01                   1
# 2         MAAREF   2020-29335    2020-01-01                   1
# 3         MAAREF   2020-29335    2020-01-01                   1
# 4         MAAREF   2020-63182    2020-01-02                   1
# ..           ...          ...           ...                 ...
# 495       MAAREF  2020-226573    2020-01-02                   1
# 496       MAAREF   2020-77582    2020-01-02                   1
# 497       MAAREF  2020-226573    2020-01-02                   1
# 498       MAAREF  2020-226570    2020-01-02                   1
# 499       MAAREF   2020-77613    2020-01-02                   1
#
#     nature_mutation  valeur_fonciere  adresse_numero adresse_suffixe  \
# 0             Vente             2055             NaN             NaN
# 1             Vente           100000             3.0             NaN
# 2             Vente           195000            11.0             NaN
# 3             Vente           195000            11.0             NaN
# 4             Vente           250000            17.0             NaN
# ..              ...              ...             ...             ...
# 495           Vente           336770            25.0             NaN
# 496           Vente            26980             NaN             NaN
# 497           Vente           336770            25.0             NaN
# 498           Vente            68900            15.0             NaN
# 499           Vente           442100             NaN             NaN
#
#         adresse_nom_voie adresse_code_voie  ...  surface_reelle_bati  \
# 0              LA QUERLA              B147  ...                  NaN
# 1    RUE DU JEU DE BOULE              0080  ...                 75.0
# 2    RUE SAUVEUR TOBELEM              8654  ...                  NaN
# 3    RUE SAUVEUR TOBELEM              8654  ...                 53.0
# 4     RUE DE KROAS PRENN              0450  ...                120.0
# ..                   ...               ...  ...                  ...
# 495    AV AUGUSTE WISSEL              0063  ...                116.0
# 496            FLORIMOND              B069  ...                  NaN
# 497    AV AUGUSTE WISSEL              0063  ...                116.0
# 498           RUE ARTAUD              0490  ...                 20.0
# 499    RUE MARCEL BENSAC              0460  ...                  NaN
#
#     nombre_pieces_principales code_nature_culture nature_culture  \
# 0                         NaN                   L         landes
# 1                         3.0                   S           sols
# 2                         0.0                 NaN            NaN
# 3                         2.0                 NaN            NaN
# 4                         3.0                   S           sols
# ..                        ...                 ...            ...
# 495                       5.0                   S           sols
# 496                       NaN                   S           sols
# 497                       5.0                   L         landes
# 498                       1.0                 NaN            NaN
# 499                       NaN                   J        jardins
#
#      code_nature_culture_speciale  nature_culture_speciale surface_terrain  \
# 0                           PATUR           Pâture plantée         10276.0
# 1                             NaN                      NaN           122.0
# 2                             NaN                      NaN             NaN
# 3                             NaN                      NaN             NaN
# 4                             NaN                      NaN           362.0
# ..                            ...                      ...             ...
# 495                           NaN                      NaN           479.0
# 496                           NaN                      NaN         10803.0
# 497                           NaN                      NaN          1725.0
# 498                           NaN                      NaN             NaN
# 499                           NaN                      NaN           437.0
#
#      longitude   latitude                                     adresse_string
# 0     6.190460  45.098818                       LA QUERLA Besse 38142 FRANCE
# 1    -0.558756  47.421083  3.0 RUE DU JEU DE BOULE Sainte-Gemmes-sur-Loir...
# 2     5.365564  43.288497  11.0 RUE SAUVEUR TOBELEM Marseille 7e Arrondis...
# 3     5.365564  43.288497  11.0 RUE SAUVEUR TOBELEM Marseille 7e Arrondis...
# 4    -3.984215  47.907844  17.0 RUE DE KROAS PRENN La Forêt-Fouesnant 299...
# ..         ...        ...                                                ...
# 495   4.847159  45.881893  25.0 AV AUGUSTE WISSEL Neuville-sur-Saône 6925...
# 496  -0.563442  44.922721                 FLORIMOND Blanquefort 33290 FRANCE
# 497   4.847159  45.881893  25.0 AV AUGUSTE WISSEL Neuville-sur-Saône 6925...
# 498   4.834711  45.781591  15.0 RUE ARTAUD Lyon 4e Arrondissement 69004 F...
# 499  -0.604879  44.954131          RUE MARCEL BENSAC Parempuyre 33290 FRANCE
#
# [500 rows x 42 columns]

# %%
"""API Module 2"""

import requests
import csv
import json



with tempfile.TemporaryDirectory() as tmpdirname2:
    data_splited.head(500).to_csv(os.path.join(tmpdirname2, '')+"Data_module2.csv")
        
    f = open(os.path.join(tmpdirname2, '')+"Data_module2.csv")
    print('make sure io.wrapper is convenient type', type(f))



    post_url = "https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF"
    post_headers = {
        "Authorization" : "Bearer key9SsqMTpaKecsn0",
        "Content-Type": "application/json"
    }

        #f = open('C:\\Users\Lenovo\Desktop\Bevouac\Data_module2.csv')
    csv_f = csv.DictReader(f, delimiter=',')

    for row in csv_f:


        data = {

      "records": [
        {
          "fields": {
              "NOM_CANDIDAT": row['NOM_CANDIDAT'],
              "id_mutation": row['id_mutation'],
              "date_mutation": row['date_mutation'],
              "numero_disposition": int(row['numero_disposition']),
              "nature_mutation": row['nature_mutation'],
              "valeur_fonciere": int(row['valeur_fonciere']),
              "adresse_numero": row['adresse_numero'],
              "adresse_suffixe": row['adresse_suffixe'],
              "adresse_nom_voie": row['adresse_nom_voie'],
              "adresse_code_voie": row['adresse_code_voie'],
              "code_postal": row['code_postal'],
              "code_commune": row['code_commune'],
              "nom_commune": row['nom_commune'],
              "code_departement": row['code_departement'],
              "ancien_code_commune": row['ancien_code_commune'],
              "ancien_nom_commune": row['ancien_nom_commune'],
              "id_parcelle": row['id_parcelle'],
              "ancien_id_parcelle": row['ancien_id_parcelle'],
              "numero_volume": row['numero_volume'],
              "lot1_numero": row['lot1_numero'],
              "lot1_surface_carrez": row['lot1_surface_carrez'],
              "lot2_numero": row['lot2_numero'],
              "lot2_surface_carrez": row['lot2_surface_carrez'],
              "lot3_numero": row['lot3_numero'],
              "lot3_surface_carrez": row['lot3_surface_carrez'],
              "lot4_numero": row['lot4_numero'],
              "lot4_surface_carrez": row['lot4_surface_carrez'],
              "lot5_numero": row['lot5_numero'],
              "lot5_surface_carrez": row['lot5_surface_carrez'],
              "nombre_lots": row['nombre_lots'],
              "code_type_local": row['code_type_local'],
              "type_local": row['type_local'],
              "surface_reelle_bati": row['surface_reelle_bati'],
              "nombre_pieces_principales": row['nombre_pieces_principales'],
              "code_nature_culture": row['code_nature_culture'],
              "nature_culture": row['nature_culture'],
              "code_nature_culture_speciale": row['code_nature_culture_speciale'],
              "nature_culture_speciale": row['nature_culture_speciale'],
              "surface_terrain": row['surface_terrain'],
              "longitude": float(row['longitude']),
              "latitude": float(row['latitude']),
              "adresse_string": row['adresse_string']

                }

            },
      ],





    }



        print(post_url)
        print(data)

        post_airtable_request = requests.post(post_url, headers = post_headers, json = data)
        print(post_airtable_request.status_code)
# Out:
# make sure io.wrapper is convenient type <class '_io.TextIOWrapper'>
# https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF
# {'records': [{'fields': {'NOM_CANDIDAT': 'MAAREF', 'id_mutation': '2020-117283', 'date_mutation': '2020-01-01', 'numero_disposition': 1, 'nature_mutation': 'Vente', 'valeur_fonciere': 2055, 'adresse_numero': '', 'adresse_suffixe': '', 'adresse_nom_voie': 'LA QUERLA', 'adresse_code_voie': 'B147', 'code_postal': '38142.0', 'code_commune': '38040', 'nom_commune': 'Besse', 'code_departement': '38', 'ancien_code_commune': '', 'ancien_nom_commune': '', 'id_parcelle': '380400000C1025', 'ancien_id_parcelle': '', 'numero_volume': '', 'lot1_numero': '', 'lot1_surface_carrez': '', 'lot2_numero': '', 'lot2_surface_carrez': '', 'lot3_numero': '', 'lot3_surface_carrez': '', 'lot4_numero': '', 'lot4_surface_carrez': '', 'lot5_numero': '', 'lot5_surface_carrez': '', 'nombre_lots': '0', 'code_type_local': '', 'type_local': '', 'surface_reelle_bati': '', 'nombre_pieces_principales': '', 'code_nature_culture': 'L', 'nature_culture': 'landes', 'code_nature_culture_speciale': 'PATUR', 'nature_culture_speciale': 'PÃ¢ture plantÃ©e', 'surface_terrain': '10276.0', 'longitude': 6.19046, 'latitude': 45.098818, 'adresse_string': 'LA QUERLA Besse 38142 FRANCE'}}]}
# 200
# https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF
# {'records': [{'fields': {'NOM_CANDIDAT': 'MAAREF', 'id_mutation': '2020-160394', 'date_mutation': '2020-01-01', 'numero_disposition': 1, 'nature_mutation': 'Vente', 'valeur_fonciere': 100000, 'adresse_numero': '3.0', 'adresse_suffixe': '', 'adresse_nom_voie': 'RUE DU JEU DE BOULE', 'adresse_code_voie': '0080', 'code_postal': '49130.0', 'code_commune': '49278', 'nom_commune': 'Sainte-Gemmes-sur-Loire', 'code_departement': '49', 'ancien_code_commune': '', 'ancien_nom_commune': '', 'id_parcelle': '49278000AM0278', 'ancien_id_parcelle': '', 'numero_volume': '', 'lot1_numero': '', 'lot1_surface_carrez': '', 'lot2_numero': '', 'lot2_surface_carrez': '', 'lot3_numero': '', 'lot3_surface_carrez': '', 'lot4_numero': '', 'lot4_surface_carrez': '', 'lot5_numero': '', 'lot5_surface_carrez': '', 'nombre_lots': '0', 'code_type_local': '1.0', 'type_local': 'Maison', 'surface_reelle_bati': '75.0', 'nombre_pieces_principales': '3.0', 'code_nature_culture': 'S', 'nature_culture': 'sols', 'code_nature_culture_speciale': '', 'nature_culture_speciale': '', 'surface_terrain': '122.0', 'longitude': -0.558756, 'latitude': 47.421083, 'adresse_string': '3.0 RUE DU JEU DE BOULE Sainte-Gemmes-sur-Loire 49130 FRANCE'}}]}
# 200
# https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF
# {'records': [{'fields': {'NOM_CANDIDAT': 'MAAREF', 'id_mutation': '2020-29335', 'date_mutation': '2020-01-01', 'numero_disposition': 1, 'nature_mutation': 'Vente', 'valeur_fonciere': 195000, 'adresse_numero': '11.0', 'adresse_suffixe': '', 'adresse_nom_voie': 'RUE SAUVEUR TOBELEM', 'adresse_code_voie': '8654', 'code_postal': '13007.0', 'code_commune': '13207', 'nom_commune': 'Marseille 7e Arrondissement', 'code_departement': '13', 'ancien_code_commune': '', 'ancien_nom_commune': '', 'id_parcelle': '132078350E0162', 'ancien_id_parcelle': '', 'numero_volume': '', 'lot1_numero': '76.0', 'lot1_surface_carrez': '', 'lot2_numero': '', 'lot2_surface_carrez': '', 'lot3_numero': '', 'lot3_surface_carrez': '', 'lot4_numero': '', 'lot4_surface_carrez': '', 'lot5_numero': '', 'lot5_surface_carrez': '', 'nombre_lots': '1', 'code_type_local': '3.0', 'type_local': 'DÃ©pendance', 'surface_reelle_bati': '', 'nombre_pieces_principales': '0.0', 'code_nature_culture': '', 'nature_culture': '', 'code_nature_culture_speciale': '', 'nature_culture_speciale': '', 'surface_terrain': '', 'longitude': 5.365564, 'latitude': 43.288497, 'adresse_string': '11.0 RUE SAUVEUR TOBELEM Marseille 7e Arrondissement 13007 FRANCE'}}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-191-ec3ad5929856> in <module>
#      92
# ---> 93         post_airtable_request = requests.post(post_url, headers = post_headers, json = data)
#      94         print(post_airtable_request.status_code)
#
# ~\document2\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#
# ~\document2\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# ~\document2\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~\document2\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~\document2\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\document2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\document2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\document2\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\document2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\document2\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\document2\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\document2\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\document2\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\document2\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\document2\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     612             try:
# --> 613                 os.unlink(fullname)
#     614             except OSError:
#
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmp3hy1twrm\\Data_module2.csv'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# ~\document2\lib\tempfile.py in onerror(func, path, exc_info)
#     802                     try:
# --> 803                         _os.unlink(path)
#     804                     # PermissionError is raised on FreeBSD for directories
#
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmp3hy1twrm\\Data_module2.csv'
#
# During handling of the above exception, another exception occurred:
#
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-191-ec3ad5929856> in <module>
#      92
#      93         post_airtable_request = requests.post(post_url, headers = post_headers, json = data)
# ---> 94         print(post_airtable_request.status_code)
#
# ~\document2\lib\tempfile.py in __exit__(self, exc, value, tb)
#     826
#     827     def __exit__(self, exc, value, tb):
# --> 828         self.cleanup()
#     829
#     830     def cleanup(self):
#
# ~\document2\lib\tempfile.py in cleanup(self)
#     830     def cleanup(self):
#     831         if self._finalizer.detach():
# --> 832             self._rmtree(self.name)
#
# ~\document2\lib\tempfile.py in _rmtree(cls, name)
#     812                 raise
#     813
# --> 814         _shutil.rmtree(name, onerror=onerror)
#     815
#     816     @classmethod
#
# ~\document2\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     735             # can't continue even if onerror hook returns
#     736             return
# --> 737         return _rmtree_unsafe(path, onerror)
#     738
#     739 # Allow introspection of whether or not the hardening against symlink
#
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     613                 os.unlink(fullname)
#     614             except OSError:
# --> 615                 onerror(os.unlink, fullname, sys.exc_info())
#     616     try:
#     617         os.rmdir(path)
#
# ~\document2\lib\tempfile.py in onerror(func, path, exc_info)
#     804                     # PermissionError is raised on FreeBSD for directories
#     805                     except (IsADirectoryError, PermissionError):
# --> 806                         cls._rmtree(path)
#     807                 except FileNotFoundError:
#     808                     pass
#
# ~\document2\lib\tempfile.py in _rmtree(cls, name)
#     812                 raise
#     813
# --> 814         _shutil.rmtree(name, onerror=onerror)
#     815
#     816     @classmethod
#
# ~\document2\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     735             # can't continue even if onerror hook returns
#     736             return
# --> 737         return _rmtree_unsafe(path, onerror)
#     738
#     739 # Allow introspection of whether or not the hardening against symlink
#
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     594             entries = list(scandir_it)
#     595     except OSError:
# --> 596         onerror(os.scandir, path, sys.exc_info())
#     597         entries = []
#     598     for entry in entries:
#
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     591 def _rmtree_unsafe(path, onerror):
#     592     try:
# --> 593         with os.scandir(path) as scandir_it:
#     594             entries = list(scandir_it)
#     595     except OSError:
#
# NotADirectoryError: [WinError 267] Nom de répertoire non valide: 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmp3hy1twrm\\Data_module2.csv'

# %%
# Out:
# int

# %% [markdown]
# ## Module 3 : Flux de données

# %% [markdown]
# - Dans cette partie, à chaque exécution le programme doit importer uniquement les données "inédites" (qui ne sont pas présentes dans la base Airtable )

# %%
        
#code of module 3
#print 500 new lines for example

with open("Data_module2.csv", "r") as readfile:
    lines = readfile.readlines()
    
    list_num = len((lines))

with tempfile.TemporaryDirectory() as tmpdirname3:
        new_data = data_splited.loc[list_num:list_num+500,:]#concaténation des lignes inédites + 500 nouvelles lignes
        new_data.to_csv(os.path.join(tmpdirname3, '')+"new_data.csv")
        f2 = open(os.path.join(tmpdirname3, '')+"new_data.csv")
        print('make sure io.wrapper is convenient type', type(f2))
        


        post_url = "https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF"
        post_headers = {
            "Authorization" : "Bearer key9SsqMTpaKecsn0",
            "Content-Type": "application/json"
        }

        #f = open('C:\\Users\Lenovo\Desktop\Bevouac\Data_module2.csv')
        csv_f2 = csv.DictReader(f2, delimiter=',')

        for row in csv_f2:


            data = {

          "records": [
            {
              "fields": {
                  "NOM_CANDIDAT": row['NOM_CANDIDAT'],
                  "id_mutation": row['id_mutation'],
                  "date_mutation": row['date_mutation'],
                  "numero_disposition": int(row['numero_disposition']),
                  "nature_mutation": row['nature_mutation'],
                  "valeur_fonciere": int(row['valeur_fonciere']),
                  "adresse_numero": row['adresse_numero'],
                  "adresse_suffixe": row['adresse_suffixe'],
                  "adresse_nom_voie": row['adresse_nom_voie'],
                  "adresse_code_voie": row['adresse_code_voie'],
                  "code_postal": row['code_postal'],
                  "code_commune": row['code_commune'],
                  "nom_commune": row['nom_commune'],
                  "code_departement": row['code_departement'],
                  "ancien_code_commune": row['ancien_code_commune'],
                  "ancien_nom_commune": row['ancien_nom_commune'],
                  "id_parcelle": row['id_parcelle'],
                  "ancien_id_parcelle": row['ancien_id_parcelle'],
                  "numero_volume": row['numero_volume'],
                  "lot1_numero": row['lot1_numero'],
                  "lot1_surface_carrez": row['lot1_surface_carrez'],
                  "lot2_numero": row['lot2_numero'],
                  "lot2_surface_carrez": row['lot2_surface_carrez'],
                  "lot3_numero": row['lot3_numero'],
                  "lot3_surface_carrez": row['lot3_surface_carrez'],
                  "lot4_numero": row['lot4_numero'],
                  "lot4_surface_carrez": row['lot4_surface_carrez'],
                  "lot5_numero": row['lot5_numero'],
                  "lot5_surface_carrez": row['lot5_surface_carrez'],
                  "nombre_lots": row['nombre_lots'],
                  "code_type_local": row['code_type_local'],
                  "type_local": row['type_local'],
                  "surface_reelle_bati": row['surface_reelle_bati'],
                  "nombre_pieces_principales": row['nombre_pieces_principales'],
                  "code_nature_culture": row['code_nature_culture'],
                  "nature_culture": row['nature_culture'],
                  "code_nature_culture_speciale": row['code_nature_culture_speciale'],
                  "nature_culture_speciale": row['nature_culture_speciale'],
                  "surface_terrain": row['surface_terrain'],
                  "longitude": float(row['longitude']),
                  "latitude": float(row['latitude']),
                  "adresse_string": row['adresse_string']

                    }

                },
          ],





        }



            print(post_url)
            print(data)

            post_airtable_request = requests.post(post_url, headers = post_headers, json = data)
            print(post_airtable_request.status_code)
# Out:
# make sure io.wrapper is convenient type <class '_io.TextIOWrapper'>
# https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF
# {'records': [{'fields': {'NOM_CANDIDAT': 'MAAREF', 'id_mutation': '2020-77613', 'date_mutation': '2020-01-02', 'numero_disposition': 1, 'nature_mutation': 'Vente', 'valeur_fonciere': 442100, 'adresse_numero': '', 'adresse_suffixe': '', 'adresse_nom_voie': 'RUE MARCEL BENSAC', 'adresse_code_voie': '0460', 'code_postal': '33290.0', 'code_commune': '33312', 'nom_commune': 'Parempuyre', 'code_departement': '33', 'ancien_code_commune': '', 'ancien_nom_commune': '', 'id_parcelle': '33312000BD0316', 'ancien_id_parcelle': '', 'numero_volume': '', 'lot1_numero': '', 'lot1_surface_carrez': '', 'lot2_numero': '', 'lot2_surface_carrez': '', 'lot3_numero': '', 'lot3_surface_carrez': '', 'lot4_numero': '', 'lot4_surface_carrez': '', 'lot5_numero': '', 'lot5_surface_carrez': '', 'nombre_lots': '0', 'code_type_local': '', 'type_local': '', 'surface_reelle_bati': '', 'nombre_pieces_principales': '', 'code_nature_culture': 'T', 'nature_culture': 'terres', 'code_nature_culture_speciale': '', 'nature_culture_speciale': '', 'surface_terrain': '85.0', 'longitude': -0.605002, 'latitude': 44.954136, 'adresse_string': 'RUE MARCEL BENSAC Parempuyre 33290 FRANCE'}}]}
# 200
# https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF
# {'records': [{'fields': {'NOM_CANDIDAT': 'MAAREF', 'id_mutation': '2020-77614', 'date_mutation': '2020-01-02', 'numero_disposition': 1, 'nature_mutation': 'Vente', 'valeur_fonciere': 156000, 'adresse_numero': '9.0', 'adresse_suffixe': '', 'adresse_nom_voie': 'RUE DE BELFORT', 'adresse_code_voie': '0149', 'code_postal': '33160.0', 'code_commune': '33449', 'nom_commune': 'Saint-MÃ©dard-en-Jalles', 'code_departement': '33', 'ancien_code_commune': '', 'ancien_nom_commune': '', 'id_parcelle': '33449000DL0118', 'ancien_id_parcelle': '', 'numero_volume': '', 'lot1_numero': '29.0', 'lot1_surface_carrez': '', 'lot2_numero': '', 'lot2_surface_carrez': '', 'lot3_numero': '', 'lot3_surface_carrez': '', 'lot4_numero': '', 'lot4_surface_carrez': '', 'lot5_numero': '', 'lot5_surface_carrez': '', 'nombre_lots': '1', 'code_type_local': '3.0', 'type_local': 'DÃ©pendance', 'surface_reelle_bati': '', 'nombre_pieces_principales': '0.0', 'code_nature_culture': '', 'nature_culture': '', 'code_nature_culture_speciale': '', 'nature_culture_speciale': '', 'surface_terrain': '', 'longitude': -0.770175, 'latitude': 44.893215999999995, 'adresse_string': '9.0 RUE DE BELFORT Saint-MÃ©dard-en-Jalles 33160 FRANCE'}}]}
# 200
# https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF
# {'records': [{'fields': {'NOM_CANDIDAT': 'MAAREF', 'id_mutation': '2020-77614', 'date_mutation': '2020-01-02', 'numero_disposition': 1, 'nature_mutation': 'Vente', 'valeur_fonciere': 156000, 'adresse_numero': '9.0', 'adresse_suffixe': '', 'adresse_nom_voie': 'RUE DE BELFORT', 'adresse_code_voie': '0149', 'code_postal': '33160.0', 'code_commune': '33449', 'nom_commune': 'Saint-MÃ©dard-en-Jalles', 'code_departement': '33', 'ancien_code_commune': '', 'ancien_nom_commune': '', 'id_parcelle': '33449000DL0118', 'ancien_id_parcelle': '', 'numero_volume': '', 'lot1_numero': '28.0', 'lot1_surface_carrez': '', 'lot2_numero': '', 'lot2_surface_carrez': '', 'lot3_numero': '', 'lot3_surface_carrez': '', 'lot4_numero': '', 'lot4_surface_carrez': '', 'lot5_numero': '', 'lot5_surface_carrez': '', 'nombre_lots': '1', 'code_type_local': '3.0', 'type_local': 'DÃ©pendance', 'surface_reelle_bati': '', 'nombre_pieces_principales': '0.0', 'code_nature_culture': '', 'nature_culture': '', 'code_nature_culture_speciale': '', 'nature_culture_speciale': '', 'surface_terrain': '', 'longitude': -0.770175, 'latitude': 44.893215999999995, 'adresse_string': '9.0 RUE DE BELFORT Saint-MÃ©dard-en-Jalles 33160 FRANCE'}}]}
# 200
# https://api.airtable.com/v0/appqmv1skloVlLyKV/DVF
# {'records': [{'fields': {'NOM_CANDIDAT': 'MAAREF', 'id_mutation': '2020-226606', 'date_mutation': '2020-01-02', 'numero_disposition': 1, 'nature_mutation': "Vente en l'Ã©tat futur d'achÃ¨vement", 'valeur_fonciere': 14871, 'adresse_numero': '28.0', 'adresse_suffixe': '', 'adresse_nom_voie': 'QUAI PAUL SEDALLIAN', 'adresse_code_voie': '5295', 'code_postal': '69009.0', 'code_commune': '69389', 'nom_commune': 'Lyon 9e Arrondissement', 'code_departement': '69', 'ancien_code_commune': '', 'ancien_nom_commune': '', 'id_parcelle': '69389000AL0027', 'ancien_id_parcelle': '', 'numero_volume': '', 'lot1_numero': '152.0', 'lot1_surface_carrez': '13.46', 'lot2_numero': '', 'lot2_surface_carrez': '', 'lot3_numero': '', 'lot3_surface_carrez': '', 'lot4_numero': '', 'lot4_surface_carrez': '', 'lot5_numero': '', 'lot5_surface_carrez': '', 'nombre_lots': '1', 'code_type_local': '', 'type_local': '', 'surface_reelle_bati': '', 'nombre_pieces_principales': '', 'code_nature_culture': '', 'nature_culture': '', 'code_nature_culture_speciale': '', 'nature_culture_speciale': '', 'surface_terrain': '', 'longitude': 4.82102, 'latitude': 45.793554, 'adresse_string': '28.0 QUAI PAUL SEDALLIAN Lyon 9e Arrondissement 69009 FRANCE'}}]}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-189-ae9cff037234> in <module>
#      92
# ---> 93             post_airtable_request = requests.post(post_url, headers = post_headers, json = data)
#      94             print(post_airtable_request.status_code)
#
# ~\document2\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#
# ~\document2\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#
# ~\document2\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#
# ~\document2\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#
# ~\document2\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\document2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\document2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\document2\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\document2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\document2\lib\http\client.py in getresponse(self)
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#
# ~\document2\lib\http\client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~\document2\lib\http\client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~\document2\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ~\document2\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#
# ~\document2\lib\ssl.py in read(self, len, buffer)
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     612             try:
# --> 613                 os.unlink(fullname)
#     614             except OSError:
#
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmp_c478vfe\\new_data.csv'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# ~\document2\lib\tempfile.py in onerror(func, path, exc_info)
#     802                     try:
# --> 803                         _os.unlink(path)
#     804                     # PermissionError is raised on FreeBSD for directories
#
# PermissionError: [WinError 32] Le processus ne peut pas accéder au fichier car ce fichier est utilisé par un autre processus: 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmp_c478vfe\\new_data.csv'
#
# During handling of the above exception, another exception occurred:
#
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-189-ae9cff037234> in <module>
#      92
#      93             post_airtable_request = requests.post(post_url, headers = post_headers, json = data)
# ---> 94             print(post_airtable_request.status_code)
#
# ~\document2\lib\tempfile.py in __exit__(self, exc, value, tb)
#     826
#     827     def __exit__(self, exc, value, tb):
# --> 828         self.cleanup()
#     829
#     830     def cleanup(self):
#
# ~\document2\lib\tempfile.py in cleanup(self)
#     830     def cleanup(self):
#     831         if self._finalizer.detach():
# --> 832             self._rmtree(self.name)
#
# ~\document2\lib\tempfile.py in _rmtree(cls, name)
#     812                 raise
#     813
# --> 814         _shutil.rmtree(name, onerror=onerror)
#     815
#     816     @classmethod
#
# ~\document2\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     735             # can't continue even if onerror hook returns
#     736             return
# --> 737         return _rmtree_unsafe(path, onerror)
#     738
#     739 # Allow introspection of whether or not the hardening against symlink
#
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     613                 os.unlink(fullname)
#     614             except OSError:
# --> 615                 onerror(os.unlink, fullname, sys.exc_info())
#     616     try:
#     617         os.rmdir(path)
#
# ~\document2\lib\tempfile.py in onerror(func, path, exc_info)
#     804                     # PermissionError is raised on FreeBSD for directories
#     805                     except (IsADirectoryError, PermissionError):
# --> 806                         cls._rmtree(path)
#     807                 except FileNotFoundError:
#     808                     pass
#
# ~\document2\lib\tempfile.py in _rmtree(cls, name)
#     812                 raise
#     813
# --> 814         _shutil.rmtree(name, onerror=onerror)
#     815
#     816     @classmethod
#
# ~\document2\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     735             # can't continue even if onerror hook returns
#     736             return
# --> 737         return _rmtree_unsafe(path, onerror)
#     738
#     739 # Allow introspection of whether or not the hardening against symlink
#
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     594             entries = list(scandir_it)
#     595     except OSError:
# --> 596         onerror(os.scandir, path, sys.exc_info())
#     597         entries = []
#     598     for entry in entries:
#
# ~\document2\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     591 def _rmtree_unsafe(path, onerror):
#     592     try:
# --> 593         with os.scandir(path) as scandir_it:
#     594             entries = list(scandir_it)
#     595     except OSError:
#
# NotADirectoryError: [WinError 267] Nom de répertoire non valide: 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmp_c478vfe\\new_data.csv'
